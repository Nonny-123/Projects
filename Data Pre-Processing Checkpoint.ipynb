# %%
import numpy as np
import pandas as pd

# %%
client_O_bills = pd.read_csv("STEG_BILLING_HISTORY.csv")
# Out:
# /var/folders/p7/d9_mnjys5ss5hl9mmyf2hsgr0000gn/T/ipykernel_42105/3039113146.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   client_O_bills = pd.read_csv("STEG_BILLING_HISTORY.csv")

# %%
client_O_bills.head(10)
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_code  \
# 0  train_Client_0   2014-03-24          11       1335667.0           203
# 1  train_Client_0   2013-03-29          11       1335667.0           203
# 2  train_Client_0   2015-03-23          11       1335667.0           203
# 3  train_Client_0   2015-07-13          11       1335667.0           207
# 4  train_Client_0   2016-11-17          11       1335667.0           207
# 5  train_Client_0   2017-07-17          11       1335667.0           207
# 6  train_Client_0   2018-12-07          11       1335667.0           207
# 7  train_Client_0   2019-03-19          11       1335667.0           207
# 8  train_Client_0   2011-07-22          11       1335667.0           203
# 9  train_Client_0   2011-11-22          11       1335667.0           203
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0               8.0                    1                    82
# ...

# %%
client_O_bills.describe()
# Out:
#          tarif_type  counter_number  counter_code  reading_remarque  \
# count  4.476749e+06    4.476701e+06  4.476749e+06      4.472218e+06
# mean   2.012804e+01    1.230595e+11  1.724884e+02      7.321713e+00
# std    1.347256e+01    1.657276e+12  1.338871e+02      1.571859e+00
# min    8.000000e+00    0.000000e+00  0.000000e+00      5.000000e+00
# 25%    1.100000e+01    1.211080e+05  5.000000e+00      6.000000e+00
# 50%    1.100000e+01    4.945610e+05  2.030000e+02      8.000000e+00
# 75%    4.000000e+01    1.115161e+06  2.070000e+02      9.000000e+00
# max    4.500000e+01    2.798115e+13  6.000000e+02      4.130000e+02
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count         4.476749e+06          4.476749e+06          4.476749e+06
# mean          1.003040e+00          4.109795e+02          1.093225e+02
# std           3.083466e-01          7.573080e+02          1.220123e+03
# ...

# %%
client_O_bills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4476749 entries, 0 to 4476748
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        float64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      float64
#  7   counter_coefficient   int64
#  8   consommation_level_1  int64
#  9   consommation_level_2  int64
#  10  consommation_level_3  int64
#  11  consommation_level_4  int64
#  12  old_index             int64
#  13  new_index             int64
#  14  months_number         int64
#  15  counter_type          object
# dtypes: float64(2), int64(10), object(4)
# memory usage: 546.5+ MB

# %%
client_O_bills.isnull().sum()
# Out:
# client_id                  0
# invoice_date               0
# tarif_type                 0
# counter_number            48
# counter_statue             0
# counter_code               0
# reading_remarque        4531
# counter_coefficient        0
# consommation_level_1       0
# consommation_level_2       0
# consommation_level_3       0
# consommation_level_4       0
# old_index                  0
# new_index                  0
# months_number              0
# counter_type               0
# dtype: int64

# %%
client_O_bills['counter_number'] = client_O_bills['counter_number'].fillna(client_O_bills['counter_number'].median())

# %%
client_O_bills['reading_remarque'] = client_O_bills['reading_remarque'].fillna(client_O_bills['reading_remarque'].median())

# %%
client_O_bills['counter_number'].describe()
# Out:
# count    4.476749e+06
# mean     1.230582e+11
# std      1.657267e+12
# min      0.000000e+00
# 25%      1.211080e+05
# 50%      4.945610e+05
# 75%      1.115161e+06
# max      2.798115e+13
# Name: counter_number, dtype: float64

# %%
client_O_bills['tarif_type'].describe()
# Out:
# count    4.476749e+06
# mean     2.012804e+01
# std      1.347256e+01
# min      8.000000e+00
# 25%      1.100000e+01
# 50%      1.100000e+01
# 75%      4.000000e+01
# max      4.500000e+01
# Name: tarif_type, dtype: float64

# %%
client_O_bills['counter_code'].describe()
# Out:
# count    4.476749e+06
# mean     1.724884e+02
# std      1.338871e+02
# min      0.000000e+00
# 25%      5.000000e+00
# 50%      2.030000e+02
# 75%      2.070000e+02
# max      6.000000e+02
# Name: counter_code, dtype: float64

# %%
client_O_bills['reading_remarque'].describe()
# Out:
# count    4.476749e+06
# mean     7.322400e+00
# std      1.571212e+00
# min      5.000000e+00
# 25%      6.000000e+00
# 50%      8.000000e+00
# 75%      9.000000e+00
# max      4.130000e+02
# Name: reading_remarque, dtype: float64

# %%
client_O_bills['counter_coefficient'].describe()
# Out:
# count    4.476749e+06
# mean     1.003040e+00
# std      3.083466e-01
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      5.000000e+01
# Name: counter_coefficient, dtype: float64

# %%
client_O_bills['consommation_level_1'].describe()
# Out:
# count    4.476749e+06
# mean     4.109795e+02
# std      7.573080e+02
# min      0.000000e+00
# 25%      7.900000e+01
# 50%      2.740000e+02
# 75%      6.000000e+02
# max      9.999100e+05
# Name: consommation_level_1, dtype: float64

# %%
client_O_bills['consommation_level_2'].describe()
# Out:
# count    4.476749e+06
# mean     1.093225e+02
# std      1.220123e+03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      9.990730e+05
# Name: consommation_level_2, dtype: float64

# %%
client_O_bills['consommation_level_3'].describe()
# Out:
# count    4.476749e+06
# mean     2.030620e+01
# std      1.574239e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.449200e+04
# Name: consommation_level_3, dtype: float64

# %%
client_O_bills['consommation_level_4'].describe()
# Out:
# count    4.476749e+06
# mean     5.292588e+01
# std      8.754725e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.479460e+05
# Name: consommation_level_4, dtype: float64

# %%
client_O_bills['old_index'].describe()
# Out:
# count    4.476749e+06
# mean     1.776700e+04
# std      4.036693e+04
# min      0.000000e+00
# 25%      1.791000e+03
# 50%      7.690000e+03
# 75%      2.166000e+04
# max      2.800280e+06
# Name: old_index, dtype: float64

# %%
client_O_bills['new_index'].describe()
# Out:
# count    4.476749e+06
# mean     1.834970e+04
# std      4.095321e+04
# min      0.000000e+00
# 25%      2.056000e+03
# 50%      8.192000e+03
# 75%      2.234300e+04
# max      2.870972e+06
# Name: new_index, dtype: float64

# %%
client_O_bills['months_number'].describe()
# Out:
# count    4.476749e+06
# mean     4.483095e+01
# std      3.128335e+03
# min      0.000000e+00
# 25%      4.000000e+00
# 50%      4.000000e+00
# 75%      4.000000e+00
# max      6.366240e+05
# Name: months_number, dtype: float64

# %%
selected_records = client_O_bills[client_O_bills['client_id'] == 'train_Client_0']
selected_records
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# 5   train_Client_0   2017-07-17          11       1335667.0              0
# 6   train_Client_0   2018-12-07          11       1335667.0              0
# 7   train_Client_0   2019-03-19          11       1335667.0              0
# 8   train_Client_0   2011-07-22          11       1335667.0              0
# 9   train_Client_0   2011-11-22          11       1335667.0              0
# 10  train_Client_0   2008-11-25          11       1335667.0              0
# ...

# %%
selected_records1 = client_O_bills.query("client_id == 'train_Client_0'")
selected_records1
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# 5   train_Client_0   2017-07-17          11       1335667.0              0
# 6   train_Client_0   2018-12-07          11       1335667.0              0
# 7   train_Client_0   2019-03-19          11       1335667.0              0
# 8   train_Client_0   2011-07-22          11       1335667.0              0
# 9   train_Client_0   2011-11-22          11       1335667.0              0
# 10  train_Client_0   2008-11-25          11       1335667.0              0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
client_O_bills['encoded_counter_type'] = encoder.fit_transform(client_O_bills['counter_type'])

# %%
client_O_bills
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10       1253571.0
# 4476745  train_Client_99998   2005-12-19          10       1253571.0
# 4476746  train_Client_99999   1996-09-25          11        560948.0
# 4476747  train_Client_99999   1996-05-28          11        560948.0
# 4476748  train_Client_99999   1996-01-25          11        560948.0
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
client_O_bills = client_O_bills.drop(['counter_statue'], axis=1)

# %%
client_O_bills[['client_id', 'invoice_date']]
# Out:
#                   client_id invoice_date
# 0            train_Client_0   2014-03-24
# 1            train_Client_0   2013-03-29
# 2            train_Client_0   2015-03-23
# 3            train_Client_0   2015-07-13
# 4            train_Client_0   2016-11-17
# ...                     ...          ...
# 4476744  train_Client_99998   2005-08-19
# 4476745  train_Client_99998   2005-12-19
# 4476746  train_Client_99999   1996-09-25
# 4476747  train_Client_99999   1996-05-28
# 4476748  train_Client_99999   1996-01-25
#
# [4476749 rows x 2 columns]
